# %%
from master_thesis import helper_functions as hf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
df = hf.pd.read_csv('../data/diagnoses_icd.csv')
icd10 = df.loc[df['icd_version'] == 10]
some_patients = icd10[['hadm_id','seq_num','icd_code']].head(200)
some_patients

patients = []
for index, row in some_patients.iterrows():
    if row['seq_num'] == 1:
        patient = []
        patients.append(patient)
        patient.append(row['icd_code'])
    else:
        patient.append(row['icd_code'])

patients_num = len(patients)
print(patients)
print(patients_num)
# Out:
# [['G3183', 'F0280', 'R441', 'R296', 'E785', 'Z8546'], ['R4182', 'G20', 'F0280', 'R609', 'E785', 'Z8546'], ['R1310', 'R0989', 'K31819', 'K219', 'K449', 'F419', 'I341', 'M810', 'Z87891'], ['S72012A', 'W010XXA', 'Y93K1', 'Y92480', 'K219', 'E7800', 'I341', 'G43909', 'Z87891', 'Z87442', 'F419', 'M810', 'Z7901'], ['I130', 'I5033', 'E872', 'N184', 'E1122', 'N2581', 'I2510', 'E11319', 'D6489', 'E785', 'Z955', 'Z86718', 'I252', 'Z2239', 'G4700', 'M1A9XX0', 'R0902', 'E1151', 'Z794', 'E669', 'Z6831'], ['D500', 'I5023', 'N184', 'E118', 'K2970', 'Z23', 'K259', 'K5730', 'I2510', 'Z87891', 'I252', 'Z955', 'I129', 'Z794', 'Z8673', 'R0789', 'Z86718', 'R791', 'T45515A', 'I70218', 'K222', 'K219'], ['I5023', 'N184', 'D631', 'E1121', 'Z86718', 'I129', 'Z955', 'I2510', 'Z7901', 'Z794', 'I340', 'I252', 'Z8673', 'Z87891', 'Z91128', 'E785'], ['C675', 'I10', 'D259', 'Z87891', 'E785', 'E890'], ['I2699', 'I82412', 'N390', 'I471', 'I10', 'I872', 'R918', 'B952', 'E039', 'E785', 'E876', 'E8342', 'G4700', 'K5900', 
# ...

# %%
gg= hf.get_similarity(patients,hf.get_ic2,hf.get_cs4,hf.get_ss6)
# Out:
# (Case:1, Patients: first_patient: 1, second_patient: 2)
# (1): concepts: first_patient_concept: 4, second_patient_concept: 3
# R296 F0280 	levels of LCA: 0 	least common ancestor is the root node
# cs#4 = 1.0
# (2): concepts: first_patient_concept: 4, second_patient_concept: 4
# R296 R609 	levels of LCA: 1 	least common ancestor: 18
# cs#4 = 0.5885276973113567
# (3): concepts: first_patient_concept: 4, second_patient_concept: 1
# R296 R4182 	levels of LCA: 1 	least common ancestor: 18
# cs#4 = 0.5885276973113567
# (4): concepts: first_patient_concept: 4, second_patient_concept: 6
# R296 Z8546 	levels of LCA: 0 	least common ancestor is the root node
# cs#4 = 1.0
# (5): concepts: first_patient_concept: 4, second_patient_concept: 5
# R296 E785 	levels of LCA: 0 	least common ancestor is the root node
# cs#4 = 1.0
# (6): concepts: first_patient_concept: 4, second_patient_concept: 2
# R296 G20 	levels of LCA: 0 	least common ancestor is the root node
# cs#4 = 1.0
# ...

# %%
X_dist_matrix = gg
X_dist_matrix
# Out:
# [[0, 0.5826796730476845, 0.8628425657704522],
#  [0.5826796730476845, 0, 0.8628425657704523],
#  [0.8628425657704522, 0.8628425657704523, 0]]

# %%
# Assuming you have 'X_dist_matrix' as your distance matrix and 'y' as corresponding labels
k = 1  # Replace 'k' with the number of neighbors you want to consider
knn_classifier = KNeighborsClassifier(n_neighbors=k, metric='precomputed')
knn_classifier.fit(X_dist_matrix, y)
